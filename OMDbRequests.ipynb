# %%
#import dependencies
import requests
import json
import pandas as pd
from config import api_key
from pprint import pprint

# %%
# Note that the ?t= is a query param for the t-itle of the
# movie we want to search for.
url = "http://www.omdbapi.com/?t="
#api_key = "&apikey=" + api_key

print(api_key)
# Out:
# f22ff569

# %%
#Loop through season numbers to return list of dictionaries for all TNG seasons

seasons = ["1","2","3","4","5","6","7"]
url = "http://www.omdbapi.com/?apikey=" + api_key + "&t=Star Trek: The Next Generation&Season="
tng_responses=[]

for season in seasons:
    #tng_responses = requests.get(url+season).json()
    #print(tng_responses)
    tng_responses.append(requests.get(url+season).json())

# %%
#Write json file with response
j=json.dumps(tng_responses)
with open('tng_data.json', 'w') as f:
    f.write(j)
    f.close()

# %%
#loop through responses to append values to lists

#create empty lists to hold values from loop
Season = []
Title = []
Episode = []
imdbRating = []

for response in tng_responses:
    Season.append(tng_responses['Season'])
    Title.append(tng_responses['Episodes'][])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-1dcea9cc336a> in <module>
#       8
#       9 for response in tng_responses:
# ---> 10     Season.append(tng_responses['Season'])
#      11     Title.append(tng_responses['Episodes']['Title'])
#
# TypeError: list indices must be integers or slices, not str

# %%
print(Season)
# Out:
# ['7', '7', '7', '7', '7']

# %%
print(Title)
# Out:
# [{'Title': 'Descent, Part II', 'Released': '1993-09-18', 'Episode': '1', 'imdbRating': '7.8', 'imdbID': 'tt0708701'}, {'Title': 'Descent, Part II', 'Released': '1993-09-18', 'Episode': '1', 'imdbRating': '7.8', 'imdbID': 'tt0708701'}, {'Title': 'Descent, Part II', 'Released': '1993-09-18', 'Episode': '1', 'imdbRating': '7.8', 'imdbID': 'tt0708701'}, {'Title': 'Descent, Part II', 'Released': '1993-09-18', 'Episode': '1', 'imdbRating': '7.8', 'imdbID': 'tt0708701'}, {'Title': 'Descent, Part II', 'Released': '1993-09-18', 'Episode': '1', 'imdbRating': '7.8', 'imdbID': 'tt0708701'}]

# %%
tng_responses
# Out:
# [{'Title': 'Star Trek: The Next Generation',
#   'Season': '1',
#   'totalSeasons': '7',
#   'Episodes': [{'Title': 'Encounter at Farpoint',
#     'Released': '1987-09-26',
#     'Episode': '1',
#     'imdbRating': '7.0',
#     'imdbID': 'tt0094030'},
#    {'Title': 'The Naked Now',
#     'Released': '1987-10-03',
#     'Episode': '2',
#     'imdbRating': '6.5',
#     'imdbID': 'tt0708810'},
#    {'Title': 'Code of Honor',
#     'Released': '1987-10-10',
#     'Episode': '3',
#     'imdbRating': '5.1',
#     'imdbID': 'tt0708689'},
#    {'Title': 'The Last Outpost',
#     'Released': '1987-10-17',
#     'Episode': '4',
#     'imdbRating': '6.3',
#     'imdbID': 'tt0708804'},
#    {'Title': 'Where No One Has Gone Before',
#     'Released': '1987-10-24',
#     'Episode': '5',
#     'imdbRating': '7.5',
#     'imdbID': 'tt0708842'},
#    {'Title': 'Lonely Among Us',
#     'Released': '1987-10-31',
#     'Episode': '6',
#     'imdbRating': '6.3',
#     'imdbID': 'tt0708743'},
# ...
